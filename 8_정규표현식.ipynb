# %%
# 08.01 Regular Expression

# %%
# Regular Expression finds pattern

import re

data = '''
park  900905-1049118
kim   700905-1059119
'''

pat = re.compile("(\d{6})[-]\d{7}")
print(pat.sub("\g<1>-*******", data))
# Out:
# park  900905-*******
# kim   700905-*******

# %%
# 08.02 Getting start with Regular Expression

# Import re(Regular Expression) module to use
# Regular Expressions

import re
p = re.compile('ab*') # * means repeat more than or equal to zero
