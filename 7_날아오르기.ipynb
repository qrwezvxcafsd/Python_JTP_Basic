# %%
# 07.01 Python & Unicode

# %%
a = 'Life is too short'
b = a.encode('utf-8')

print(b)
print(type(b))

print('')

c = '한글'
print(c.encode('utf-8'))
print(c.encode('euc-kr'))
print(type(c.encode('utf-8')))
print(type(c.encode('euc-kr')))
# Out:
# b'Life is too short'
# <class 'bytes'>
#
# b'\xed\x95\x9c\xea\xb8\x80'
# b'\xc7\xd1\xb1\xdb'
# <class 'bytes'>
# <class 'bytes'>

# %%
d = c.encode('utf-8')
print(d.decode('utf-8'))
# Out:
# 한글
